# %%
pip install --upgrade google-genai
# Out:
# Collecting google-genai
#   Downloading google_genai-1.64.0-py3-none-any.whl.metadata (53 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from google-genai) (4.12.1)
# Collecting google-auth<3.0.0,>=2.47.0 (from google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading google_auth-2.48.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from google-genai) (0.28.1)
# Collecting pydantic<3.0.0,>=2.9.0 (from google-genai)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from google-genai) (2.32.5)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai)
#   Downloading websockets-15.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from google-genai) (4.15.0)
# Collecting distro<2,>=1.7.0 (from google-genai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting sniffio (from google-genai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting aiohttp>=3.10.11 (from google-genai)
#   Downloading aiohttp-3.13.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp>=3.10.11->google-genai)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp>=3.10.11->google-genai)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from aiohttp>=3.10.11->google-genai) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.10.11->google-genai)
#   Downloading frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.10.11->google-genai)
#   Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.10.11->google-genai)
#   Downloading propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.10.11->google-genai)
#   Downloading yarl-1.22.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (75 kB)
# Requirement already satisfied: idna>=2.8 in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading cryptography-46.0.5-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: certifi in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Downloading pydantic_core-2.41.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.9.0->google-genai)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.0.0)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading pyasn1-0.6.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pycparser in /Users/mohanrajsubramaniam/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (3.0)
# Downloading google_genai-1.64.0-py3-none-any.whl (728 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.8/728.8 kB 20.4 MB/s eta 0:00:00
# Downloading aiohttp-3.13.3-cp311-cp311-macosx_11_0_arm64.whl (494 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading google_auth-2.48.0-py3-none-any.whl (236 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 39.6 MB/s eta 0:00:00
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading websockets-15.0.1-cp311-cp311-macosx_11_0_arm64.whl (173 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cryptography-46.0.5-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 57.4 MB/s eta 0:00:00
# Downloading frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl (50 kB)
# Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl (44 kB)
# Downloading propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl (47 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading yarl-1.22.0-cp311-cp311-macosx_11_0_arm64.whl (94 kB)
# Downloading pyasn1-0.6.2-py3-none-any.whl (83 kB)
# Installing collected packages: websockets, typing-inspection, tenacity, sniffio, pydantic-core, pyasn1, propcache, multidict, frozenlist, distro, annotated-types, aiohappyeyeballs, yarl, rsa, pydantic, pyasn1-modules, cryptography, aiosignal, google-auth, aiohttp, google-genai
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 annotated-types-0.7.0 cryptography-46.0.5 distro-1.9.0 frozenlist-1.8.0 google-auth-2.48.0 google-genai-1.64.0 multidict-6.7.1 propcache-0.4.1 pyasn1-0.6.2 pyasn1-modules-0.4.2 pydantic-2.12.5 pydantic-core-2.41.5 rsa-4.9.1 sniffio-1.3.1 tenacity-9.1.4 typing-inspection-0.4.2 websockets-15.0.1 yarl-1.22.0
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from google import genai

client = genai.Client(api_key="GEMINI_API_KEY")

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[6], line 5
#       1 from google import genai
#       3 client = genai.Client(api_key="GEMINI_API_KEY")
# ----> 5 response = client.models.generate_content(
#       6     model="gemini-3-flash-preview", contents="Explain how AI works in a few words"
#       7 )
#       8 print(response.text)
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/google/genai/models.py:5621, in Models.generate_content(self, model, contents, config)
#    5619 while remaining_remote_calls_afc > 0:
#    5620   i += 1
# -> 5621   response = self._generate_content(
#    5622       model=model, contents=contents, config=parsed_config
#    5623   )
#    5625   function_map = _extra_utils.get_function_map(parsed_config)
#    5626   if not function_map:
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/google/genai/models.py:4283, in Models._generate_content(self, model, contents, config)
#    4280 request_dict = _common.convert_to_dict(request_dict)
#    4281 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4283 response = self._api_client.request(
#    4284     'post', path, request_dict, http_options
#    4285 )
#    4287 if config is not None and getattr(
#    4288     config, 'should_return_http_response', None
#    4289 ):
#    4290   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:1396, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1386 def request(
#    1387     self,
#    1388     http_method: str,
#    (...)   1391     http_options: Optional[HttpOptionsOrDict] = None,
#    1392 ) -> SdkHttpResponse:
#    1393   http_request = self._build_request(
#    1394       http_method, path, request_dict, http_options
#    1395   )
# -> 1396   response = self._request(http_request, http_options, stream=False)
#    1397   response_body = (
#    1398       response.response_stream[0] if response.response_stream else ''
#    1399   )
#    1400   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:1232, in BaseApiClient._request(self, http_request, http_options, stream)
#    1229     retry = tenacity.Retrying(**retry_kwargs)
#    1230     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1232 return self._retry(self._request_once, http_request, stream)
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:1209, in BaseApiClient._request_once(self, http_request, stream)
#    1201 else:
#    1202   response = self._httpx_client.request(
#    1203       method=http_request.method,
#    1204       url=http_request.url,
#    (...)   1207       timeout=http_request.timeout,
#    1208   )
# -> 1209   errors.APIError.raise_for_response(response)
#    1210   return HttpResponse(
#    1211       response.headers, response if stream else [response.text]
#    1212   )
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/google/genai/errors.py:134, in APIError.raise_for_response(cls, response)
#     131 else:
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File ~/PycharmProjects/python_learning/.venv/lib/python3.11/site-packages/google/genai/errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     145 """Raises an appropriate APIError subclass based on the status code.
#     146
#     147 Args:
#    (...)    156   APIError: For other error status codes.
#     157 """
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#     161   raise ServerError(status_code, response_json, response)
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}
